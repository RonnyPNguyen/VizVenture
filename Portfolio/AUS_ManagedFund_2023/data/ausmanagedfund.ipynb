# %%
import pandas as pd
import numpy as np
import os
import json

cwd = os.getcwd()
fundSummary = pd.read_excel(cwd + '/Summary_Managed Fund_Institutions.xlsx', sheet_name='Data1')

# %%
df = fundSummary.iloc[9:,:]

# %%
df1 = df.iloc[-(5*4):,0:13]
df1['Date'] = pd.to_datetime(df['Date'])
df1['Date'] = df1['Date'].dt.to_period('Q')
df1
# Out:
#        Date CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS ;  \
# 132  2019Q1                                            2845639
# 133  2019Q2                                            2948700
# 134  2019Q3                                            3020729
# 135  2019Q4                                            3076706
# 136  2020Q1                                            2909683
# 137  2020Q2                                            2990186
# 138  2020Q3                                            3004179
# 139  2020Q4                                            3153638
# 140  2021Q1                                            3249674
# 141  2021Q2                                            3415766
# 142  2021Q3                                            3487112
# 143  2021Q4                                            3575036
# 144  2022Q1                                            3549403
# 145  2022Q2                                            3429851
# 146  2022Q3                                            3444398
# 147  2022Q4                                            3526404
# 148  2023Q1                                            3637893
# 149  2023Q2                                            3713711
# 150  2023Q3                                            3731578
# 151  2023Q4                                            3883663
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Deposits ;  \
# 132                                             242863
# 133                                             249459
# 134                                             254030
# 135                                             250324
# 136                                             282260
# 137                                             288149
# 138                                             280116
# 139                                             266209
# 140                                             265285
# 141                                             270914
# 142                                             262025
# 143                                             255449
# 144                                             255131
# 145                                             279597
# 146                                             279892
# 147                                             281621
# 148                                             292244
# 149                                             301130
# 150                                             309407
# 151                                             313287
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Short term securities ;  \
# 132                                              90390
# 133                                              88298
# 134                                              81045
# 135                                              87772
# 136                                              89067
# 137                                              99340
# 138                                              97464
# 139                                              93339
# 140                                              91797
# 141                                              78440
# 142                                              76447
# 143                                              79055
# 144                                              81339
# 145                                              80361
# 146                                              81890
# 147                                              82815
# 148                                              83349
# 149                                              77860
# 150                                              80459
# 151                                              81148
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Bonds, etc. ;  \
# 132                                              99467
# 133                                             106644
# 134                                             111109
# 135                                             118227
# 136                                             107603
# 137                                             110684
# 138                                             110141
# 139                                             115981
# 140                                             116280
# 141                                             117950
# 142                                             118190
# 143                                             115420
# 144                                             115515
# 145                                             117135
# 146                                             121222
# 147                                             127453
# 148                                             142145
# 149                                             147867
# 150                                             149059
# 151                                             160412
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Derivatives ;  \
# 132                                              38866
# 133                                              33434
# 134                                              34738
# 135                                              35389
# 136                                              54570
# 137                                              48686
# 138                                              35205
# 139                                              43626
# 140                                              37926
# 141                                              37969
# 142                                              38468
# 143                                              43556
# 144                                              50891
# 145                                              45127
# 146                                              46385
# 147                                              44658
# 148                                              45566
# 149                                              45555
# 150                                              52575
# 151                                              63881
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Loans and placements ;  \
# 132                                              33397
# 133                                              32730
# 134                                              34705
# 135                                              35751
# 136                                              35244
# 137                                              32414
# 138                                              31801
# 139                                              31804
# 140                                              31190
# 141                                              32052
# 142                                              33886
# 143                                              31962
# 144                                              26870
# 145                                              27359
# 146                                              26135
# 147                                              26420
# 148                                              26930
# 149                                              26975
# 150                                              27721
# 151                                              28041
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Shares ;  \
# 132                                             472181
# 133                                             499240
# 134                                             511505
# 135                                             514075
# 136                                             396381
# 137                                             465548
# 138                                             470350
# 139                                             546615
# 140                                             574564
# 141                                             629947
# 142                                             639676
# 143                                             660843
# 144                                             680346
# 145                                             602047
# 146                                             614595
# 147                                             657958
# 148                                             670902
# 149                                             675978
# 150                                             671989
# 151                                             723843
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Units in trusts ;  \
# 132                                             783452
# 133                                             811979
# 134                                             829470
# 135                                             832544
# 136                                             746336
# 137                                             761860
# 138                                             783411
# 139                                             820200
# 140                                             841068
# 141                                             883190
# 142                                             903246
# 143                                             916205
# 144                                             893935
# 145                                             851049
# 146                                             848970
# 147                                             869586
# 148                                             891131
# 149                                             898856
# 150                                             891374
# 151                                             906126
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Other financial assets ;  \
# 132                                             222573
# 133                                             227054
# 134                                             227253
# 135                                             226990
# 136                                             242168
# 137                                             237813
# 138                                             243980
# 139                                             236418
# 140                                             239300
# 141                                             243864
# 142                                             251343
# 143                                             255459
# 144                                             258967
# 145                                             270845
# 146                                             275811
# 147                                             274467
# 148                                             274150
# 149                                             276286
# 150                                             288639
# 151                                             291669
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Land, buildings and equipment ;  \
# 132                                             293161
# 133                                             296601
# 134                                             304198
# 135                                             313390
# 136                                             314602
# 137                                             308984
# 138                                             310663
# 139                                             315398
# 140                                             321788
# 141                                             335361
# 142                                             346023
# 143                                             364018
# 144                                             367008
# 145                                             369645
# 146                                             363296
# 147                                             361075
# 148                                             360198
# 149                                             358740
# 150                                             359460
# 151                                             357156
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Other non-financial assets ;  \
# 132                                              32276
# 133                                              30632
# 134                                              30168
# 135                                              30312
# 136                                              31683
# 137                                              30355
# 138                                              31263
# 139                                              31379
# 140                                              32852
# 141                                              34517
# 142                                              34630
# 143                                              35279
# 144                                              35580
# 145                                              36517
# 146                                              37751
# 147                                              37137
# 148                                              37763
# 149                                              38039
# 150                                              38567
# 151                                              38193
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Overseas assets ;
# 132                                             537014
# 133                                             572630
# 134                                             602508
# 135                                             631933
# 136                                             609769
# 137                                             606354
# 138                                             609785
# 139                                             652668
# 140                                             697622
# 141                                             751561
# 142                                             783179
# 143                                             817789
# 144                                             783819
# 145                                             750170
# 146                                             748453
# 147                                             763216
# 148                                             813515
# 149                                             866425
# 150                                             862326
# 151                                             919906

# %%
df1_pct = df1.copy()
df1_pct.iloc[:,2:] = df1_pct.iloc[:,2:].apply(lambda x: x/x.sum()*100, axis=1).round(2)
df1_pct.sample(5)
# Out:
#        Date CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS ;  \
# 147  2022Q4                                            3526404
# 134  2019Q3                                            3020729
# 148  2023Q1                                            3637893
# 140  2021Q1                                            3249674
# 145  2022Q2                                            3429851
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Deposits ;  \
# 147                                               7.99
# 134                                               8.41
# 148                                               8.03
# 140                                               8.16
# 145                                               8.15
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Short term securities ;  \
# 147                                               2.35
# 134                                               2.68
# 148                                               2.29
# 140                                               2.82
# 145                                               2.34
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Bonds, etc. ;  \
# 147                                               3.61
# 134                                               3.68
# 148                                               3.91
# 140                                               3.58
# 145                                               3.42
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Derivatives ;  \
# 147                                               1.27
# 134                                               1.15
# 148                                               1.25
# 140                                               1.17
# 145                                               1.32
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Loans and placements ;  \
# 147                                               0.75
# 134                                               1.15
# 148                                               0.74
# 140                                               0.96
# 145                                                0.8
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Shares ;  \
# 147                                              18.66
# 134                                              16.93
# 148                                              18.44
# 140                                              17.68
# 145                                              17.55
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Units in trusts ;  \
# 147                                              24.66
# 134                                              27.46
# 148                                               24.5
# 140                                              25.88
# 145                                              24.81
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Other financial assets ;  \
# 147                                               7.78
# 134                                               7.52
# 148                                               7.54
# 140                                               7.36
# 145                                                7.9
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Land, buildings and equipment ;  \
# 147                                              10.24
# 134                                              10.07
# 148                                                9.9
# 140                                                9.9
# 145                                              10.78
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Other non-financial assets ;  \
# 147                                               1.05
# 134                                                1.0
# 148                                               1.04
# 140                                               1.01
# 145                                               1.06
#
#     CONSOLIDATED ASSETS TOTAL MANAGED FUNDS INSTITUTIONS, Overseas assets ;
# 147                                              21.64
# 134                                              19.95
# 148                                              22.36
# 140                                              21.47
# 145                                              21.87

# %%
df1_pct_sort = df1_pct.iloc[:,[0,1,12,8,7,10,2]]
df1_pct_sort['Other'] = 100 - df1_pct.iloc[:,[12,8,7,10,2]].apply(lambda x: x.sum(), axis=1)
df1_pct_sort = df1_pct_sort.round(2)
df1_pct_sort.columns = ['Period', 'Total Assets',
    'Overseas assets',
    'Units in trusts',
    'Shares',
    'Land, buildings and equipment',
    'Deposits',
    'Others']
df1_pct_sort.sample(5)
# Out:
# /var/folders/m5/2zm1zfkj0f34zf9y6m_q_6yw0000gn/T/ipykernel_3962/1274713417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_pct_sort['Other'] = 100 - df1_pct.iloc[:,[12,8,7,10,2]].apply(lambda x: x.sum(), axis=1)
#      Period Total Assets Overseas assets Units in trusts Shares  \
# 137  2020Q2      2990186           20.28           25.48  15.57
# 145  2022Q2      3429851           21.87           24.81  17.55
# 142  2021Q3      3487112           22.46            25.9  18.34
# 151  2023Q4      3883663           23.69           23.33  18.64
# 150  2023Q3      3731578           23.11           23.89  18.01
#
#     Land, buildings and equipment Deposits  Others
# 137                         10.33     9.64   18.70
# 145                         10.78     8.15   16.84
# 142                          9.92     7.51   15.87
# 151                           9.2     8.07   17.07
# 150                          9.63     8.29   17.07

# %%
df2 = df.iloc[-9:,20:].reset_index(drop=True)

# %%
df2_growth = df2.copy()
for i, d in df2_growth.iterrows():
    if i == 0:
        df2_growth.loc[i,:] = 0
    else:
        df2_growth.loc[i,:] = (df2.loc[i,:] - df2.loc[i-1,:])/df2.loc[i-1,:]*100
df2_growth = df2_growth.iloc[1:,:]
df2_growth = df2_growth.astype(float).round(2)
df2_growth.columns = ['Total managed funds assets','Life insurance corporations','Superannuation (pension) funds','Public offer (retail) unit trusts','Friendly societies','Common funds','Cash management trusts']
df2_growth["Period"] = ['Q1_2022','Q2_2022','Q3_2022','Q4_2022','Q1_2023','Q2_2023','Q3_2023','Q4_2023']
df2_growth = df2_growth.iloc[:,[7,0,1,2,3,4,5,6]]
df2_growth
# Out:
#     Period  Total managed funds assets  Life insurance corporations  \
# 1  Q1_2022                       -1.32                        -1.49
# 2  Q2_2022                       -4.17                        -4.57
# 3  Q3_2022                        0.20                        -1.04
# 4  Q4_2022                        2.75                         0.39
# 5  Q1_2023                        3.29                         2.08
# 6  Q2_2023                        1.97                        -0.89
# 7  Q3_2023                        0.37                        -0.37
# 8  Q4_2023                        4.13                         1.06
#
#    Superannuation (pension) funds  Public offer (retail) unit trusts  \
# 1                           -1.04                              -3.28
# 2                           -4.41                              -1.48
# 3                            0.28                               0.37
# 4                            2.93                               2.45
# 5                            3.53                               1.76
# 6                            2.17                               1.37
# 7                            0.71                              -2.00
# 8                            4.35                               3.48
#
#    Friendly societies  Common funds  Cash management trusts
# 1               -2.49          0.46                   -2.39
# 2               -3.83         -5.14                  -14.14
# 3                0.55          1.49                   -6.68
# 4                2.67          0.60                   -3.83
# 5                2.68          3.76                    3.99
# 6                3.12          1.85                   -2.17
# 7                0.46          2.83                   -0.40
# 8                5.17          3.32                   -0.45

# %%
df2_growth_pct = pd.DataFrame(columns=['Period', 'Institution', 'Rate'])
for i, d in df2_growth.iterrows():
    rows_to_add = []
    for j in range(1, 8):
        row = {'Period': d['Period'], 'Institution': df2_growth.columns[j], 'Rate': d[j]}
        rows_to_add.append(row)
    temp_df = pd.DataFrame(rows_to_add)
    df2_growth_pct = pd.concat([df2_growth_pct, temp_df], ignore_index=True)
# Out:
# /var/folders/m5/2zm1zfkj0f34zf9y6m_q_6yw0000gn/T/ipykernel_3962/2167543399.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row = {'Period': d['Period'], 'Institution': df2_growth.columns[j], 'Rate': d[j]}
# /var/folders/m5/2zm1zfkj0f34zf9y6m_q_6yw0000gn/T/ipykernel_3962/2167543399.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df2_growth_pct = pd.concat([df2_growth_pct, temp_df], ignore_index=True)

# %%
def first_letters(text,skip_letter='('):
    # Split the text into words and collect the first letter of each word
    return ''.join(word[0] for word in text.split() if not word.lower().startswith(skip_letter.lower()))
df2_growth_pct['identifier'] = df2_growth_pct['Institution'].apply(first_letters)
df2_growth_pct.sample(5)
# Out:
#      Period                     Institution  Rate identifier
# 50  Q4_2023     Life insurance corporations  1.06        Lic
# 37  Q2_2023  Superannuation (pension) funds  2.17         Sf
# 15  Q3_2022     Life insurance corporations -1.04        Lic
# 27  Q4_2022          Cash management trusts -3.83        Cmt
# 26  Q4_2022                    Common funds  0.60         Cf

# %%
df1_pct_sort.to_csv(cwd + '/df1_pct_sort.csv', index=False)
df2_growth_pct.to_csv(cwd + '/df2_growth_pct.csv', index=False)
